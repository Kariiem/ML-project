# %%
import pandas as pd
import utils

# %%
# Read the csv file and preprocess it: convert qualitative attributes to integers
train = pd.read_csv("train.csv")
# drop duplicates
train = train.drop_duplicates()
X = train.agg(utils.transform_dataset) # utils.transform_dataset is a dicitionary which applies a transforming function on each column
X["Is_Int"] = 0

X["Is_Int"] = (abs(round(X["Veg_Consump"]) - X["Veg_Consump"]) < 0.01).astype(int) \
+ (abs(round(X["Water_Consump"]) - X["Water_Consump"]) < 0.01).astype(int) \
+ (abs(round(X["Phys_Act"]) - X["Phys_Act"]) < 0.01).astype(int) \
+ (abs(round(X["Time_E_Dev"]) - X["Time_E_Dev"]) < 0.01).astype(int) \
+ (abs(round(X["Age"]) - X["Age"]) < 0.01).astype(int) \
+ (abs(round(X["Meal_Count"]) - X["Meal_Count"]) < 0.01).astype(int)
y= X["Body_Level"]
y= y-1
X = X.drop("Body_Level", axis=1)

# %%
# Split the dataset into train and test sets
# sklearn
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4)

# %%
from imblearn.over_sampling import SMOTE

# Initialize the LazyClassifier and fit the training data
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader



# Convert the data into PyTorch tensors
X_train_tensor = torch.from_numpy(X_train.values).float()
X_test_tensor = torch.from_numpy(X_test.values).float()
y_train_tensor = torch.from_numpy(y_train.values).long()
y_test_tensor = torch.from_numpy(y_test.values).long()

# Define the neural network architecture
class Net(nn.Module):
    def __init__(self, dropout=0):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(17, 32)
        self.fc2 = nn.Linear(32, 64)
        self.fc3 = nn.Linear(64, 32)
        self.fc4 = nn.Linear(32, 15)
        self.fc5 = nn.Linear(15, 4)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        # x= self.dropout(x)
        x = torch.relu(self.fc2(x))
        x= self.dropout(x)
        x = torch.relu(self.fc3(x))
        # x= self.dropout(x)
        x = torch.relu(self.fc4(x))
        x = self.fc5(x)
        # x = torch.softmax(x, dim=1)  # Apply the softmax function along the class dimension

        return x

# %%
# Create a PyTorch data loader for the training data
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Initialize the neural network, loss function, and optimizer
net = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# Train the neural network
for epoch in range(500):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    print('Epoch %d loss: %.3f' % (epoch + 1, running_loss / len(train_loader)))
# Out:
# Epoch 1 loss: 1.300
# Epoch 2 loss: 1.036
# Epoch 3 loss: 0.754
# Epoch 4 loss: 0.658
# Epoch 5 loss: 0.581
# Epoch 6 loss: 0.512
# Epoch 7 loss: 0.457
# Epoch 8 loss: 0.408
# Epoch 9 loss: 0.383
# Epoch 10 loss: 0.370
# Epoch 11 loss: 0.335
# Epoch 12 loss: 0.328
# Epoch 13 loss: 0.297
# Epoch 14 loss: 0.291
# Epoch 15 loss: 0.276
# Epoch 16 loss: 0.253
# Epoch 17 loss: 0.263
# Epoch 18 loss: 0.252
# Epoch 19 loss: 0.234
# Epoch 20 loss: 0.234
# Epoch 21 loss: 0.227
# Epoch 22 loss: 0.225
# Epoch 23 loss: 0.226
# Epoch 24 loss: 0.230
# Epoch 25 loss: 0.204
# Epoch 26 loss: 0.220
# Epoch 27 loss: 0.199
# Epoch 28 loss: 0.226
# Epoch 29 loss: 0.207
# Epoch 30 loss: 0.218
# Epoch 31 loss: 0.216
# Epoch 32 loss: 0.204
# Epoch 33 loss: 0.185
# Epoch 34 loss: 0.182
# Epoch 35 loss: 0.196
# Epoch 36 loss: 0.187
# Epoch 37 loss: 0.177
# Epoch 38 loss: 0.169
# Epoch 39 loss: 0.198
# Epoch 40 loss: 0.206
# Epoch 41 loss: 0.183
# Epoch 42 loss: 0.170
# Epoch 43 loss: 0.163
# Epoch 44 loss: 0.167
# Epoch 45 loss: 0.163
# Epoch 46 loss: 0.170
# Epoch 47 loss: 0.169
# Epoch 48 loss: 0.161
# Epoch 49 loss: 0.154
# Epoch 50 loss: 0.180
# Epoch 51 loss: 0.152
# Epoch 52 loss: 0.158
# Epoch 53 loss: 0.157
# Epoch 54 loss: 0.146
# Epoch 55 loss: 0.139
# Epoch 56 loss: 0.163
# Epoch 57 loss: 0.144
# Epoch 58 loss: 0.138
# Epoch 59 loss: 0.141
# Epoch 60 loss: 0.146
# Epoch 61 loss: 0.137
# Epoch 62 loss: 0.136
# Epoch 63 loss: 0.139
# Epoch 64 loss: 0.129
# Epoch 65 loss: 0.142
# Epoch 66 loss: 0.133
# Epoch 67 loss: 0.157
# Epoch 68 loss: 0.127
# Epoch 69 loss: 0.125
# Epoch 70 loss: 0.133
# Epoch 71 loss: 0.122
# Epoch 72 loss: 0.117
# Epoch 73 loss: 0.127
# Epoch 74 loss: 0.143
# Epoch 75 loss: 0.123
# Epoch 76 loss: 0.118
# Epoch 77 loss: 0.142
# Epoch 78 loss: 0.122
# Epoch 79 loss: 0.104
# Epoch 80 loss: 0.131
# Epoch 81 loss: 0.109
# Epoch 82 loss: 0.113
# Epoch 83 loss: 0.116
# Epoch 84 loss: 0.107
# Epoch 85 loss: 0.132
# Epoch 86 loss: 0.131
# Epoch 87 loss: 0.126
# Epoch 88 loss: 0.114
# Epoch 89 loss: 0.112
# Epoch 90 loss: 0.111
# Epoch 91 loss: 0.098
# Epoch 92 loss: 0.115
# Epoch 93 loss: 0.108
# Epoch 94 loss: 0.106
# Epoch 95 loss: 0.113
# Epoch 96 loss: 0.096
# Epoch 97 loss: 0.094
# Epoch 98 loss: 0.099
# Epoch 99 loss: 0.105
# Epoch 100 loss: 0.086
# Epoch 101 loss: 0.106
# Epoch 102 loss: 0.091
# Epoch 103 loss: 0.093
# Epoch 104 loss: 0.087
# Epoch 105 loss: 0.127
# Epoch 106 loss: 0.121
# Epoch 107 loss: 0.097
# Epoch 108 loss: 0.092
# Epoch 109 loss: 0.111
# Epoch 110 loss: 0.104
# Epoch 111 loss: 0.083
# Epoch 112 loss: 0.083
# Epoch 113 loss: 0.077
# Epoch 114 loss: 0.089
# Epoch 115 loss: 0.093
# Epoch 116 loss: 0.110
# Epoch 117 loss: 0.096
# Epoch 118 loss: 0.120
# Epoch 119 loss: 0.094
# Epoch 120 loss: 0.124
# Epoch 121 loss: 0.097
# Epoch 122 loss: 0.096
# Epoch 123 loss: 0.079
# Epoch 124 loss: 0.095
# Epoch 125 loss: 0.133
# Epoch 126 loss: 0.095
# Epoch 127 loss: 0.079
# Epoch 128 loss: 0.089
# Epoch 129 loss: 0.088
# Epoch 130 loss: 0.077
# Epoch 131 loss: 0.100
# Epoch 132 loss: 0.079
# Epoch 133 loss: 0.089
# Epoch 134 loss: 0.071
# Epoch 135 loss: 0.069
# Epoch 136 loss: 0.072
# Epoch 137 loss: 0.072
# Epoch 138 loss: 0.071
# Epoch 139 loss: 0.104
# Epoch 140 loss: 0.076
# Epoch 141 loss: 0.089
# Epoch 142 loss: 0.078
# Epoch 143 loss: 0.079
# Epoch 144 loss: 0.083
# Epoch 145 loss: 0.066
# Epoch 146 loss: 0.065
# Epoch 147 loss: 0.093
# Epoch 148 loss: 0.071
# Epoch 149 loss: 0.067
# Epoch 150 loss: 0.091
# Epoch 151 loss: 0.080
# Epoch 152 loss: 0.090
# Epoch 153 loss: 0.090
# Epoch 154 loss: 0.088
# Epoch 155 loss: 0.068
# Epoch 156 loss: 0.076
# Epoch 157 loss: 0.089
# Epoch 158 loss: 0.089
# Epoch 159 loss: 0.068
# Epoch 160 loss: 0.062
# Epoch 161 loss: 0.066
# Epoch 162 loss: 0.088
# Epoch 163 loss: 0.077
# Epoch 164 loss: 0.080
# Epoch 165 loss: 0.077
# Epoch 166 loss: 0.067
# Epoch 167 loss: 0.070
# Epoch 168 loss: 0.054
# Epoch 169 loss: 0.058
# Epoch 170 loss: 0.074
# Epoch 171 loss: 0.068
# Epoch 172 loss: 0.065
# Epoch 173 loss: 0.060
# Epoch 174 loss: 0.059
# Epoch 175 loss: 0.065
# Epoch 176 loss: 0.061
# Epoch 177 loss: 0.068
# Epoch 178 loss: 0.092
# Epoch 179 loss: 0.072
# Epoch 180 loss: 0.055
# Epoch 181 loss: 0.080
# Epoch 182 loss: 0.061
# Epoch 183 loss: 0.086
# Epoch 184 loss: 0.158
# Epoch 185 loss: 0.067
# Epoch 186 loss: 0.058
# Epoch 187 loss: 0.064
# Epoch 188 loss: 0.079
# Epoch 189 loss: 0.118
# Epoch 190 loss: 0.053
# Epoch 191 loss: 0.050
# Epoch 192 loss: 0.047
# Epoch 193 loss: 0.068
# Epoch 194 loss: 0.064
# Epoch 195 loss: 0.049
# Epoch 196 loss: 0.060
# Epoch 197 loss: 0.062
# Epoch 198 loss: 0.048
# Epoch 199 loss: 0.056
# Epoch 200 loss: 0.052
# Epoch 201 loss: 0.052
# Epoch 202 loss: 0.045
# Epoch 203 loss: 0.054
# Epoch 204 loss: 0.048
# Epoch 205 loss: 0.108
# Epoch 206 loss: 0.089
# Epoch 207 loss: 0.043
# Epoch 208 loss: 0.058
# Epoch 209 loss: 0.058
# Epoch 210 loss: 0.049
# Epoch 211 loss: 0.049
# Epoch 212 loss: 0.044
# Epoch 213 loss: 0.052
# Epoch 214 loss: 0.052
# Epoch 215 loss: 0.060
# Epoch 216 loss: 0.055
# Epoch 217 loss: 0.050
# Epoch 218 loss: 0.071
# Epoch 219 loss: 0.068
# Epoch 220 loss: 0.050
# Epoch 221 loss: 0.046
# Epoch 222 loss: 0.042
# Epoch 223 loss: 0.049
# Epoch 224 loss: 0.052
# Epoch 225 loss: 0.044
# Epoch 226 loss: 0.059
# Epoch 227 loss: 0.038
# Epoch 228 loss: 0.045
# Epoch 229 loss: 0.048
# Epoch 230 loss: 0.060
# Epoch 231 loss: 0.070
# Epoch 232 loss: 0.044
# Epoch 233 loss: 0.043
# Epoch 234 loss: 0.037
# Epoch 235 loss: 0.042
# Epoch 236 loss: 0.051
# Epoch 237 loss: 0.077
# Epoch 238 loss: 0.050
# Epoch 239 loss: 0.053
# Epoch 240 loss: 0.053
# Epoch 241 loss: 0.043
# Epoch 242 loss: 0.047
# Epoch 243 loss: 0.053
# Epoch 244 loss: 0.045
# Epoch 245 loss: 0.044
# Epoch 246 loss: 0.035
# Epoch 247 loss: 0.055
# Epoch 248 loss: 0.046
# Epoch 249 loss: 0.053
# Epoch 250 loss: 0.073
# Epoch 251 loss: 0.084
# Epoch 252 loss: 0.037
# Epoch 253 loss: 0.031
# Epoch 254 loss: 0.031
# Epoch 255 loss: 0.039
# Epoch 256 loss: 0.041
# Epoch 257 loss: 0.047
# Epoch 258 loss: 0.088
# Epoch 259 loss: 0.068
# Epoch 260 loss: 0.037
# Epoch 261 loss: 0.113
# Epoch 262 loss: 0.045
# Epoch 263 loss: 0.037
# Epoch 264 loss: 0.035
# Epoch 265 loss: 0.041
# Epoch 266 loss: 0.047
# Epoch 267 loss: 0.040
# Epoch 268 loss: 0.108
# Epoch 269 loss: 0.049
# Epoch 270 loss: 0.037
# Epoch 271 loss: 0.029
# Epoch 272 loss: 0.087
# Epoch 273 loss: 0.052
# Epoch 274 loss: 0.033
# Epoch 275 loss: 0.043
# Epoch 276 loss: 0.048
# Epoch 277 loss: 0.039
# Epoch 278 loss: 0.023
# Epoch 279 loss: 0.027
# Epoch 280 loss: 0.029
# Epoch 281 loss: 0.033
# Epoch 282 loss: 0.040
# Epoch 283 loss: 0.028
# Epoch 284 loss: 0.032
# Epoch 285 loss: 0.035
# Epoch 286 loss: 0.024
# Epoch 287 loss: 0.022
# Epoch 288 loss: 0.029
# Epoch 289 loss: 0.035
# Epoch 290 loss: 0.029
# Epoch 291 loss: 0.070
# Epoch 292 loss: 0.038
# Epoch 293 loss: 0.042
# Epoch 294 loss: 0.035
# Epoch 295 loss: 0.024
# Epoch 296 loss: 0.065
# Epoch 297 loss: 0.028
# Epoch 298 loss: 0.055
# Epoch 299 loss: 0.044
# Epoch 300 loss: 0.032
# Epoch 301 loss: 0.021
# Epoch 302 loss: 0.019
# Epoch 303 loss: 0.049
# Epoch 304 loss: 0.021
# Epoch 305 loss: 0.022
# Epoch 306 loss: 0.029
# Epoch 307 loss: 0.035
# Epoch 308 loss: 0.048
# Epoch 309 loss: 0.029
# Epoch 310 loss: 0.037
# Epoch 311 loss: 0.017
# Epoch 312 loss: 0.031
# Epoch 313 loss: 0.018
# Epoch 314 loss: 0.020
# Epoch 315 loss: 0.122
# Epoch 316 loss: 0.033
# Epoch 317 loss: 0.018
# Epoch 318 loss: 0.024
# Epoch 319 loss: 0.017
# Epoch 320 loss: 0.018
# Epoch 321 loss: 0.016
# Epoch 322 loss: 0.035
# Epoch 323 loss: 0.063
# Epoch 324 loss: 0.049
# Epoch 325 loss: 0.024
# Epoch 326 loss: 0.021
# Epoch 327 loss: 0.022
# Epoch 328 loss: 0.022
# Epoch 329 loss: 0.019
# Epoch 330 loss: 0.029
# Epoch 331 loss: 0.018
# Epoch 332 loss: 0.046
# Epoch 333 loss: 0.034
# Epoch 334 loss: 0.022
# Epoch 335 loss: 0.038
# Epoch 336 loss: 0.023
# Epoch 337 loss: 0.031
# Epoch 338 loss: 0.022
# Epoch 339 loss: 0.080
# Epoch 340 loss: 0.033
# Epoch 341 loss: 0.052
# Epoch 342 loss: 0.027
# Epoch 343 loss: 0.038
# Epoch 344 loss: 0.017
# Epoch 345 loss: 0.014
# Epoch 346 loss: 0.013
# Epoch 347 loss: 0.013
# Epoch 348 loss: 0.019
# Epoch 349 loss: 0.035
# Epoch 350 loss: 0.018
# Epoch 351 loss: 0.012
# Epoch 352 loss: 0.009
# Epoch 353 loss: 0.013
# Epoch 354 loss: 0.013
# Epoch 355 loss: 0.025
# Epoch 356 loss: 0.042
# Epoch 357 loss: 0.033
# Epoch 358 loss: 0.025
# Epoch 359 loss: 0.028
# Epoch 360 loss: 0.022
# Epoch 361 loss: 0.029
# Epoch 362 loss: 0.027
# Epoch 363 loss: 0.045
# Epoch 364 loss: 0.020
# Epoch 365 loss: 0.067
# Epoch 366 loss: 0.019
# Epoch 367 loss: 0.014
# Epoch 368 loss: 0.014
# Epoch 369 loss: 0.010
# Epoch 370 loss: 0.013
# Epoch 371 loss: 0.009
# Epoch 372 loss: 0.009
# Epoch 373 loss: 0.104
# Epoch 374 loss: 0.066
# Epoch 375 loss: 0.019
# Epoch 376 loss: 0.010
# Epoch 377 loss: 0.009
# Epoch 378 loss: 0.029
# Epoch 379 loss: 0.022
# Epoch 380 loss: 0.007
# Epoch 381 loss: 0.009
# Epoch 382 loss: 0.032
# Epoch 383 loss: 0.076
# Epoch 384 loss: 0.032
# Epoch 385 loss: 0.018
# Epoch 386 loss: 0.028
# Epoch 387 loss: 0.018
# Epoch 388 loss: 0.013
# Epoch 389 loss: 0.014
# Epoch 390 loss: 0.010
# Epoch 391 loss: 0.007
# Epoch 392 loss: 0.007
# Epoch 393 loss: 0.065
# Epoch 394 loss: 0.018
# Epoch 395 loss: 0.014
# Epoch 396 loss: 0.009
# Epoch 397 loss: 0.010
# Epoch 398 loss: 0.044
# Epoch 399 loss: 0.018
# Epoch 400 loss: 0.009
# Epoch 401 loss: 0.033
# Epoch 402 loss: 0.029
# Epoch 403 loss: 0.030
# Epoch 404 loss: 0.015
# Epoch 405 loss: 0.008
# Epoch 406 loss: 0.004
# Epoch 407 loss: 0.007
# Epoch 408 loss: 0.005
# Epoch 409 loss: 0.005
# Epoch 410 loss: 0.007
# Epoch 411 loss: 0.013
# Epoch 412 loss: 0.007
# Epoch 413 loss: 0.006
# Epoch 414 loss: 0.020
# Epoch 415 loss: 0.030
# Epoch 416 loss: 0.054
# Epoch 417 loss: 0.021
# Epoch 418 loss: 0.020
# Epoch 419 loss: 0.013
# Epoch 420 loss: 0.031
# Epoch 421 loss: 0.013
# Epoch 422 loss: 0.005
# Epoch 423 loss: 0.009
# Epoch 424 loss: 0.003
# Epoch 425 loss: 0.002
# Epoch 426 loss: 0.003
# Epoch 427 loss: 0.003
# Epoch 428 loss: 0.033
# Epoch 429 loss: 0.127
# Epoch 430 loss: 0.039
# Epoch 431 loss: 0.008
# Epoch 432 loss: 0.006
# Epoch 433 loss: 0.005
# Epoch 434 loss: 0.005
# Epoch 435 loss: 0.004
# Epoch 436 loss: 0.003
# Epoch 437 loss: 0.003
# Epoch 438 loss: 0.003
# Epoch 439 loss: 0.005
# Epoch 440 loss: 0.029
# Epoch 441 loss: 0.035
# Epoch 442 loss: 0.023
# Epoch 443 loss: 0.084
# Epoch 444 loss: 0.026
# Epoch 445 loss: 0.008
# Epoch 446 loss: 0.006
# Epoch 447 loss: 0.024
# Epoch 448 loss: 0.007
# Epoch 449 loss: 0.005
# Epoch 450 loss: 0.004
# Epoch 451 loss: 0.014
# Epoch 452 loss: 0.003
# Epoch 453 loss: 0.003
# Epoch 454 loss: 0.004
# Epoch 455 loss: 0.003
# Epoch 456 loss: 0.002
# Epoch 457 loss: 0.003
# Epoch 458 loss: 0.002
# Epoch 459 loss: 0.002
# Epoch 460 loss: 0.002
# Epoch 461 loss: 0.003
# Epoch 462 loss: 0.002
# Epoch 463 loss: 0.002
# Epoch 464 loss: 0.001
# Epoch 465 loss: 0.001
# Epoch 466 loss: 0.001
# Epoch 467 loss: 0.001
# Epoch 468 loss: 0.001
# Epoch 469 loss: 0.001
# Epoch 470 loss: 0.002
# Epoch 471 loss: 0.002
# Epoch 472 loss: 0.001
# Epoch 473 loss: 0.001
# Epoch 474 loss: 0.001
# Epoch 475 loss: 0.001
# Epoch 476 loss: 0.001
# Epoch 477 loss: 0.001
# Epoch 478 loss: 0.035
# Epoch 479 loss: 0.209
# Epoch 480 loss: 0.037
# Epoch 481 loss: 0.023
# Epoch 482 loss: 0.009
# Epoch 483 loss: 0.010
# Epoch 484 loss: 0.007
# Epoch 485 loss: 0.009
# Epoch 486 loss: 0.005
# Epoch 487 loss: 0.003
# Epoch 488 loss: 0.004
# Epoch 489 loss: 0.003
# Epoch 490 loss: 0.002
# Epoch 491 loss: 0.002
# Epoch 492 loss: 0.001
# Epoch 493 loss: 0.002
# Epoch 494 loss: 0.001
# Epoch 495 loss: 0.001
# Epoch 496 loss: 0.001
# Epoch 497 loss: 0.001
# Epoch 498 loss: 0.001
# Epoch 499 loss: 0.001
# Epoch 500 loss: 0.001

# %%
with torch.no_grad():
    outputs = net(X_train_tensor)
    _, predicted_train = torch.max(outputs.data, 1)
# print acc
print('Accuracy of the network on the train data: %.3f' % (100 * torch.sum(y_train_tensor == predicted_train) / len(y_train_tensor)))


with torch.no_grad():
    outputs = net(X_test_tensor)
    _, predicted_test = torch.max(outputs.data, 1)
# print acc
print('Accuracy of the network on the test data: %.3f' % (100 * torch.sum(y_test_tensor == predicted_test) / len(y_test_tensor)))


# get F1 score
from sklearn.metrics import f1_score
print("f1_train",f1_score(y_train_tensor, predicted_train, average='macro'))
print("f1_test",f1_score(y_test_tensor, predicted_test, average='macro'))

# f1 train
# Out:
# Accuracy of the network on the train data: 100.000
# Accuracy of the network on the test data: 92.321
# f1_train 1.0
# f1_test 0.9106609829885894

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# test to test and val
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=.2, random_state=42)

from imblearn.over_sampling import SMOTE

# Initialize the LazyClassifier and fit the training data
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
X_train_tensor = torch.from_numpy(X_train.values).float()
X_test_tensor = torch.from_numpy(X_test.values).float()
X_val_tensor = torch.from_numpy(X_val.values).float()

y_train_tensor = torch.from_numpy(y_train.values).long()
y_test_tensor = torch.from_numpy(y_test.values).long()
y_val_tensor = torch.from_numpy(y_val.values).long()

net = Net(dropout=0.2)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.001, weight_decay=0.001)

# Train the neural network with L2 regularization
count =0
model_fin = None
last_val_acc = 0
for epoch in range(500):
    running_loss = 0.0
    count +=1
    for i, data in enumerate(train_loader, 0):
        # Get the inputs
        inputs, labels = data

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Print statistics
        running_loss += loss.item()
    if count % 50 == 0:    # print every 2000 mini-batches
        print('[%d, %5d] loss: %.3f' %
                (epoch + 1, i + 1, running_loss / 2000))
        running_loss = 0.0
        # print acc
        with torch.no_grad():
            outputs = net(X_train_tensor)
            _, predicted_train = torch.max(outputs.data, 1)
        print('Accuracy of the network on the train data: %.3f' % (100 * torch.sum(y_train_tensor == predicted_train) / len(y_train_tensor)))
        # get val
        with torch.no_grad():
            outputs = net(X_val_tensor)
            _, predicted_val = torch.max(outputs.data, 1)
        val_acc= 100 * torch.sum(y_val_tensor == predicted_val) / len(y_val_tensor)
        if (val_acc >= last_val_acc) :
            last_val_acc = val_acc
            model_fin = net
        print('Accuracy of the network on the val data: %.3f' % (100 * torch.sum(y_val_tensor == predicted_val) / len(y_val_tensor)))
# Out:
# [50,    53] loss: 0.005
# Accuracy of the network on the train data: 88.426
# Accuracy of the network on the val data: 98.305
# [100,    53] loss: 0.003
# Accuracy of the network on the train data: 92.130
# Accuracy of the network on the val data: 96.610
# [150,    53] loss: 0.002
# Accuracy of the network on the train data: 94.769
# Accuracy of the network on the val data: 98.305
# [200,    53] loss: 0.002
# Accuracy of the network on the train data: 94.676
# Accuracy of the network on the val data: 100.000
# [250,    53] loss: 0.002
# Accuracy of the network on the train data: 95.556
# Accuracy of the network on the val data: 94.915
# [300,    53] loss: 0.001
# Accuracy of the network on the train data: 94.722
# Accuracy of the network on the val data: 98.305
# [350,    53] loss: 0.001
# Accuracy of the network on the train data: 96.204
# Accuracy of the network on the val data: 100.000
# [400,    53] loss: 0.001
# Accuracy of the network on the train data: 95.509
# Accuracy of the network on the val data: 100.000
# [450,    53] loss: 0.001
# Accuracy of the network on the train data: 96.389
# Accuracy of the network on the val data: 100.000
# [500,    53] loss: 0.001
# Accuracy of the network on the train data: 96.019
# Accuracy of the network on the val data: 100.000

# %%
#get acc test
with torch.no_grad():
    outputs = model_fin(X_test_tensor)
    _, predicted_test = torch.max(outputs.data, 1)
# print acc
print('Accuracy of the network on the test data: %.3f' % (100 * torch.sum(y_test_tensor == predicted_test) / len(y_test_tensor)))
# get f1
print('F1 score of the network on the test data: %.3f' % (f1_score(y_test_tensor, predicted_test, average='macro')))


# get acc train
with torch.no_grad():
    outputs = model_fin(X_train_tensor)
    _, predicted_train = torch.max(outputs.data, 1)
# print acc
print('Accuracy of the network on the train data: %.3f' % (100 * torch.sum(y_train_tensor == predicted_train) / len(y_train_tensor)))
# Out:
# Accuracy of the network on the test data: 96.154
# F1 score of the network on the test data: 0.951
# Accuracy of the network on the train data: 95.880
