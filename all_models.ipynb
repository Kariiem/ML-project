# %%
import pandas as pd
import utils

# %%
# Read the csv file and preprocess it: convert qualitative attributes to integers
train = pd.read_csv("train.csv")
X = train.agg(utils.transform_dataset) # utils.transform_dataset is a dicitionary which applies a transforming function on each column

X_train = X.sample(frac=0.8, random_state=42)
X_test = X.drop(X_train.index)

Y_train = X_train["Body_Level"]
Y_test = X_test["Body_Level"]

X_train = X_train.drop("Body_Level", axis=1)
X_test = X_test.drop("Body_Level", axis=1)
display(X_train)
display(X_test)
# Out:
#       Gender        Age    Height      Weight  H_Cal_Consump  Veg_Consump  \
# 1233       0  21.768834  1.733383  135.524857              1     3.000000
# 529        1  19.565496  1.705584   78.025625              0     1.936479
# 1177       1  18.000000  1.803527  108.251044              1     2.000000
# 432        0  21.012569  1.758628   78.370039              1     3.000000
# 363        0  23.000000  1.500000   55.000000              1     3.000000
# ...      ...        ...       ...         ...            ...          ...
# 476        1  23.000000  1.700740   81.322970              1     2.000000
# 157        0  18.288205  1.713564   50.000000              1     1.140615
# 16         0  19.948140  1.530884   39.371523              1     1.522001
# 1072       0  38.148845  1.557808   79.661693              1     2.000000
# 546        0  20.000000  1.650000   75.000000              1     3.000000
#
#       Water_Consump  Alcohol_Consump  Smoking  Meal_Count  Food_Between_Meals  \
# 1233       1.485736                1        0    3.000000                   1
# 529        2.159987                1        0    2.837388                   1
# 1177       2.530157                0        0    1.709546                   1
# 432        2.000000                1        0    1.000000                   1
# 363        2.000000                1        0    3.000000                   1
# ...             ...              ...      ...         ...                 ...
# 476        1.519700                1        0    2.720642                   1
# 157        1.000000                1        0    3.471536                   1
# 16         1.981260                1        0    3.000000                   1
# 1072       1.274774                1        0    3.000000                   1
# 546        2.000000                0        0    1.000000                   1
#
#       Fam_Hist  H_Cal_Burn  Phys_Act  Time_E_Dev  Transport
# 1233         1           0  1.950374    0.869238          0
# 529          1           0  1.475772    0.646514          0
# 1177         1           0  1.000000    0.645400          0
# 432          1           0  2.971832    0.000000          0
# 363          1           0  1.000000    0.000000          2
# ...        ...         ...       ...         ...        ...
# 476          1           0  0.279375    1.043435          0
# 157          0           0  2.000000    1.000000          0
# 16           0           0  2.306844    0.720454          0
# 1072         1           0  0.000000    0.000000          1
# 546          1           0  1.000000    1.000000          0
#
# [1182 rows x 16 columns]
#       Gender        Age    Height      Weight  H_Cal_Consump  Veg_Consump  \
# 1          1  19.799054  1.743702   54.927529              1     2.000000
# 8          0  23.444286  1.596466   44.594588              0     2.594653
# 13         0  16.928791  1.710948   45.248627              1     2.910733
# 14         1  17.000000  1.800000   58.000000              1     2.000000
# 20         1  18.381382  1.722547   53.783977              1     2.000000
# ...      ...        ...       ...         ...            ...          ...
# 1450       0  23.000000  1.611058   84.191125              1     2.141280
# 1453       1  26.004294  1.844751  105.025808              1     3.000000
# 1459       0  25.653233  1.664940  110.922170              1     3.000000
# 1462       0  20.978166  1.721057  132.054793              1     3.000000
# 1473       0  20.908785  1.700996  126.490236              1     3.000000
#
#       Water_Consump  Alcohol_Consump  Smoking  Meal_Count  Food_Between_Meals  \
# 1          2.847264                1        0    3.289260                   1
# 8          1.916812                0        0    1.882158                   2
# 13         2.204263                1        0    3.125440                   1
# 14         2.000000                0        0    3.000000                   2
# 20         2.072194                1        0    3.131032                   1
# ...             ...              ...      ...         ...                 ...
# 1450       2.519841                0        0    2.989112                   1
# 1453       2.925029                1        0    3.000000                   1
# 1459       1.604075                1        0    3.000000                   1
# 1462       1.678791                1        0    3.000000                   1
# 1473       1.242832                1        0    3.000000                   1
#
#       Fam_Hist  H_Cal_Burn  Phys_Act  Time_E_Dev  Transport
# 1            1           0  1.680844    2.000000          0
# 8            0           0  0.417119    0.000000          0
# 13           0           0  2.407906    1.403037          0
# 14           0           0  2.000000    1.000000          4
# 20           1           0  1.487987    2.000000          0
# ...        ...         ...       ...         ...        ...
# 1450         1           0  2.111370    0.013483          0
# 1453         1           0  2.000000    1.758865          0
# 1459         1           0  0.029728    0.200122          0
# 1462         1           0  1.682490    0.818871          0
# 1473         1           0  0.530925    0.575969          0
#
# [295 rows x 16 columns]

# %%
X_train.head()
# print name of all heads
print(X_train.columns.values)
# Out:
# ['Gender' 'Age' 'Height' 'Weight' 'H_Cal_Consump' 'Veg_Consump'
#  'Water_Consump' 'Alcohol_Consump' 'Smoking' 'Meal_Count'
#  'Food_Between_Meals' 'Fam_Hist' 'H_Cal_Burn' 'Phys_Act' 'Time_E_Dev'
#  'Transport']

# %%
Y_train.unique()
# Out:
# array([4, 3, 2, 1])

# %%
import pandas as pd
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# %%
# Initialize the LazyClassifier and fit the training data
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, Y_train, Y_test)

# Print the results
print(models)
# Out:
# 100%|██████████| 29/29 [00:03<00:00,  9.47it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.99               0.98    None      0.99
# ExtraTreesClassifier               0.97               0.94    None      0.97
# RandomForestClassifier             0.97               0.94    None      0.97
# BaggingClassifier                  0.96               0.92    None      0.95
# LogisticRegression                 0.96               0.91    None      0.95
# DecisionTreeClassifier             0.94               0.91    None      0.94
# SVC                                0.94               0.90    None      0.94
# LinearSVC                          0.91               0.84    None      0.91
# CalibratedClassifierCV             0.92               0.84    None      0.91
# QuadraticDiscriminantAnalysis      0.86               0.83    None      0.85
# ExtraTreeClassifier                0.86               0.83    None      0.87
# LinearDiscriminantAnalysis         0.87               0.81    None      0.87
# LabelSpreading                     0.87               0.79    None      0.87
# LabelPropagation                   0.87               0.79    None      0.87
# KNeighborsClassifier               0.84               0.74    None      0.83
# Perceptron                         0.83               0.72    None      0.83
# SGDClassifier                      0.82               0.71    None      0.82
# AdaBoostClassifier                 0.78               0.70    None      0.78
# NearestCentroid                    0.74               0.67    None      0.74
# PassiveAggressiveClassifier        0.81               0.66    None      0.80
# RidgeClassifier                    0.74               0.62    None      0.73
# RidgeClassifierCV                  0.74               0.61    None      0.72
# BernoulliNB                        0.71               0.61    None      0.71
# GaussianNB                         0.69               0.60    None      0.65
# DummyClassifier                    0.50               0.25    None      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       1.09
# ExtraTreesClassifier                 0.15
# RandomForestClassifier               0.22
# BaggingClassifier                    0.05
# LogisticRegression                   0.05
# DecisionTreeClassifier               0.01
# SVC                                  0.07
# LinearSVC                            0.16
# CalibratedClassifierCV               0.55
# QuadraticDiscriminantAnalysis        0.01
# ExtraTreeClassifier                  0.01
# LinearDiscriminantAnalysis           0.03
# LabelSpreading                       0.13
# LabelPropagation                     0.07
# KNeighborsClassifier                 0.03
# Perceptron                           0.01
# SGDClassifier                        0.03
# AdaBoostClassifier                   0.16
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# BernoulliNB                          0.04
# GaussianNB                           0.01
# DummyClassifier                      0.01

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.99               0.98    None      0.99
# ExtraTreesClassifier               0.97               0.94    None      0.97
# RandomForestClassifier             0.97               0.94    None      0.97
# BaggingClassifier                  0.96               0.92    None      0.95
# LogisticRegression                 0.96               0.91    None      0.95
# DecisionTreeClassifier             0.94               0.91    None      0.94
# SVC                                0.94               0.90    None      0.94
# LinearSVC                          0.91               0.84    None      0.91
# CalibratedClassifierCV             0.92               0.84    None      0.91
# QuadraticDiscriminantAnalysis      0.86               0.83    None      0.85
# ExtraTreeClassifier                0.86               0.83    None      0.87
# LinearDiscriminantAnalysis         0.87               0.81    None      0.87
# LabelSpreading                     0.87               0.79    None      0.87
# LabelPropagation                   0.87               0.79    None      0.87
# KNeighborsClassifier               0.84               0.74    None      0.83
# Perceptron                         0.83               0.72    None      0.83
# SGDClassifier                      0.82               0.71    None      0.82
# AdaBoostClassifier                 0.78               0.70    None      0.78
# NearestCentroid                    0.74               0.67    None      0.74
# PassiveAggressiveClassifier        0.81               0.66    None      0.80
# RidgeClassifier                    0.74               0.62    None      0.73
# RidgeClassifierCV                  0.74               0.61    None      0.72
# BernoulliNB                        0.71               0.61    None      0.71
# GaussianNB                         0.69               0.60    None      0.65
# DummyClassifier                    0.50               0.25    None      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       1.09
# ExtraTreesClassifier                 0.15
# RandomForestClassifier               0.22
# BaggingClassifier                    0.05
# LogisticRegression                   0.05
# DecisionTreeClassifier               0.01
# SVC                                  0.07
# LinearSVC                            0.16
# CalibratedClassifierCV               0.55
# QuadraticDiscriminantAnalysis        0.01
# ExtraTreeClassifier                  0.01
# LinearDiscriminantAnalysis           0.03
# LabelSpreading                       0.13
# LabelPropagation                     0.07
# KNeighborsClassifier                 0.03
# Perceptron                           0.01
# SGDClassifier                        0.03
# AdaBoostClassifier                   0.16
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# BernoulliNB                          0.04
# GaussianNB                           0.01
# DummyClassifier                      0.01

# %%
from imblearn.over_sampling import SMOTE

# Initialize the LazyClassifier and fit the training data
sm = SMOTE(random_state=42)
X_train_smote, Y_train_smote = sm.fit_resample(X_train, Y_train)
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train_smote, X_test, Y_train_smote, Y_test)

# Print the results
print(models)
# Out:
# 100%|██████████| 29/29 [00:03<00:00,  7.68it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.99               0.98    None      0.99
# LogisticRegression                 0.98               0.96    None      0.98
# DecisionTreeClassifier             0.97               0.95    None      0.97
# BaggingClassifier                  0.97               0.95    None      0.97
# RandomForestClassifier             0.97               0.95    None      0.97
# ExtraTreesClassifier               0.96               0.95    None      0.96
# SVC                                0.94               0.91    None      0.94
# NuSVC                              0.88               0.87    None      0.88
# QuadraticDiscriminantAnalysis      0.89               0.86    None      0.88
# LabelSpreading                     0.91               0.86    None      0.90
# LabelPropagation                   0.91               0.86    None      0.90
# LinearSVC                          0.90               0.86    None      0.90
# CalibratedClassifierCV             0.90               0.85    None      0.90
# LinearDiscriminantAnalysis         0.86               0.85    None      0.87
# ExtraTreeClassifier                0.87               0.84    None      0.87
# KNeighborsClassifier               0.88               0.83    None      0.88
# SGDClassifier                      0.87               0.82    None      0.87
# Perceptron                         0.81               0.77    None      0.81
# PassiveAggressiveClassifier        0.81               0.73    None      0.81
# RidgeClassifier                    0.75               0.68    None      0.75
# RidgeClassifierCV                  0.75               0.68    None      0.75
# GaussianNB                         0.70               0.64    None      0.66
# AdaBoostClassifier                 0.71               0.63    None      0.70
# NearestCentroid                    0.67               0.58    None      0.68
# BernoulliNB                        0.65               0.55    None      0.63
# DummyClassifier                    0.11               0.25    None      0.02
#
#                                Time Taken
# Model
# LGBMClassifier                       0.44
# LogisticRegression                   0.07
# DecisionTreeClassifier               0.02
# BaggingClassifier                    0.07
# RandomForestClassifier               0.28
# ExtraTreesClassifier                 0.18
# SVC                                  0.12
# NuSVC                                0.26
# QuadraticDiscriminantAnalysis        0.01
# LabelSpreading                       0.32
# LabelPropagation                     0.17
# LinearSVC                            0.29
# CalibratedClassifierCV               1.17
# LinearDiscriminantAnalysis           0.02
# ExtraTreeClassifier                  0.01
# KNeighborsClassifier                 0.02
# SGDClassifier                        0.03
# Perceptron                           0.02
# PassiveAggressiveClassifier          0.02
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.01
# GaussianNB                           0.01
# AdaBoostClassifier                   0.18
# NearestCentroid                      0.01
# BernoulliNB                          0.01
# DummyClassifier                      0.01

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.99               0.98    None      0.99
# LogisticRegression                 0.98               0.96    None      0.98
# DecisionTreeClassifier             0.97               0.95    None      0.97
# BaggingClassifier                  0.97               0.95    None      0.97
# RandomForestClassifier             0.97               0.95    None      0.97
# ExtraTreesClassifier               0.96               0.95    None      0.96
# SVC                                0.94               0.91    None      0.94
# NuSVC                              0.88               0.87    None      0.88
# QuadraticDiscriminantAnalysis      0.89               0.86    None      0.88
# LabelSpreading                     0.91               0.86    None      0.90
# LabelPropagation                   0.91               0.86    None      0.90
# LinearSVC                          0.90               0.86    None      0.90
# CalibratedClassifierCV             0.90               0.85    None      0.90
# LinearDiscriminantAnalysis         0.86               0.85    None      0.87
# ExtraTreeClassifier                0.87               0.84    None      0.87
# KNeighborsClassifier               0.88               0.83    None      0.88
# SGDClassifier                      0.87               0.82    None      0.87
# Perceptron                         0.81               0.77    None      0.81
# PassiveAggressiveClassifier        0.81               0.73    None      0.81
# RidgeClassifier                    0.75               0.68    None      0.75
# RidgeClassifierCV                  0.75               0.68    None      0.75
# GaussianNB                         0.70               0.64    None      0.66
# AdaBoostClassifier                 0.71               0.63    None      0.70
# NearestCentroid                    0.67               0.58    None      0.68
# BernoulliNB                        0.65               0.55    None      0.63
# DummyClassifier                    0.11               0.25    None      0.02
#
#                                Time Taken
# Model
# LGBMClassifier                       0.44
# LogisticRegression                   0.07
# DecisionTreeClassifier               0.02
# BaggingClassifier                    0.07
# RandomForestClassifier               0.28
# ExtraTreesClassifier                 0.18
# SVC                                  0.12
# NuSVC                                0.26
# QuadraticDiscriminantAnalysis        0.01
# LabelSpreading                       0.32
# LabelPropagation                     0.17
# LinearSVC                            0.29
# CalibratedClassifierCV               1.17
# LinearDiscriminantAnalysis           0.02
# ExtraTreeClassifier                  0.01
# KNeighborsClassifier                 0.02
# SGDClassifier                        0.03
# Perceptron                           0.02
# PassiveAggressiveClassifier          0.02
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.01
# GaussianNB                           0.01
# AdaBoostClassifier                   0.18
# NearestCentroid                      0.01
# BernoulliNB                          0.01
# DummyClassifier                      0.01
