# %%
from models import *

# %%
plt.plot(X_train["BMI"], Y_train, "o")
plt.show()
plt.plot(X_train["Veg_Consump"],Y_train, "o")
plt.plot(X_train["Water_Consump"], Y_train, "o")

# %%
plt.plot(X_train_smote["BMI"], Y_train_smote, 'o')

# %%
# run the models on the original dataset
svm_clf = svm_model(X_train, Y_train, X_test, Y_test)

random_forest_clf = random_forest_model(X_train, Y_train, X_test, Y_test)

naive_bayes_clf = naive_bayes_model(X_train, Y_train, X_test, Y_test)

svm_model_best_params(X_train, Y_train, X_test, Y_test)
# Out:
# svm: kernel=rbf, C=1.0, gamma='scale'
#               precision    recall  f1-score   support
#
#            1       0.78      0.86      0.82        44
#            2       0.78      0.42      0.55        50
#            3       0.65      0.94      0.77        66
#            4       0.97      0.88      0.92       133
#
#     accuracy                           0.81       293
#    macro avg       0.79      0.78      0.76       293
# weighted avg       0.83      0.81      0.81       293
#
# svm_clf||                Bias:  0.18569965870307167 Variance:  0.18771331058020477 Error:  0.014948805460750857
#
#
# random forest: n_estimators=100, max_depth=None
#               precision    recall  f1-score   support
#
#            1       1.00      0.95      0.98        44
#            2       0.96      1.00      0.98        50
#            3       1.00      0.98      0.99        66
#            4       0.99      1.00      1.00       133
#
#     accuracy                           0.99       293
#    macro avg       0.99      0.98      0.99       293
# weighted avg       0.99      0.99      0.99       293
#
# random_forest_clf||      Bias:  0.009590443686006827 Variance:  0.006825938566552901 Error:  0.004436860068259386
#
#
# naive bayes: GaussianNB
#               precision    recall  f1-score   support
#
#            1       1.00      0.80      0.89        44
#            2       0.69      1.00      0.82        50
#            3       0.92      0.52      0.66        66
#            4       0.86      0.96      0.91       133
#
#     accuracy                           0.84       293
#    macro avg       0.87      0.82      0.82       293
# weighted avg       0.87      0.84      0.83       293
#
# naive_bayes_clf||        Bias:  0.16573378839590444 Variance:  0.16040955631399317 Error:  0.04249146757679181
#
#
# svm: kernel=linear C=10 gamma=0.01
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        44
#            2       1.00      1.00      1.00        50
#            3       1.00      0.98      0.99        66
#            4       0.99      1.00      1.00       133
#
#     accuracy                           1.00       293
#    macro avg       1.00      1.00      1.00       293
# weighted avg       1.00      1.00      1.00       293
#
# svm_clf||                Bias:  0.014283276450511946 Variance:  0.0034129692832764505 Error:  0.011689419795221844
# SVC(C=10, gamma=0.01, kernel='linear')

# %%
# run the models on the original dataset
svm_clf = svm_model(X_train_smote, Y_train_smote, X_test, Y_test)

random_forest_clf = random_forest_model(X_train_smote, Y_train_smote, X_test, Y_test)

naive_bayes_clf = naive_bayes_model(X_train_smote, Y_train_smote, X_test, Y_test)

svm_model_best_params(X_train_smote, Y_train_smote, X_test, Y_test)
# Out:
# svm: kernel=rbf, C=1.0, gamma='scale'
#               precision    recall  f1-score   support
#
#            1       0.97      0.89      0.93        44
#            2       0.90      0.92      0.91        50
#            3       0.77      0.97      0.86        66
#            4       0.98      0.88      0.93       133
#
#     accuracy                           0.91       293
#    macro avg       0.91      0.91      0.91       293
# weighted avg       0.92      0.91      0.91       293
#
# svm_clf||                Bias:  0.09592150170648464 Variance:  0.09556313993174062 Error:  0.008856655290102388
#
#
# random forest: n_estimators=100, max_depth=None
#               precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99        44
#            2       0.98      1.00      0.99        50
#            3       1.00      1.00      1.00        66
#            4       1.00      1.00      1.00       133
#
#     accuracy                           1.00       293
#    macro avg       1.00      0.99      0.99       293
# weighted avg       1.00      1.00      1.00       293
#
# random_forest_clf||      Bias:  0.007679180887372014 Variance:  0.010238907849829351 Error:  0.0033105802047781567
#
#
# naive bayes: GaussianNB
#               precision    recall  f1-score   support
#
#            1       1.00      0.80      0.89        44
#            2       0.69      1.00      0.82        50
#            3       0.93      0.64      0.76        66
#            4       0.91      0.96      0.93       133
#
#     accuracy                           0.87       293
#    macro avg       0.88      0.85      0.85       293
# weighted avg       0.89      0.87      0.87       293
#
# naive_bayes_clf||        Bias:  0.15472696245733789 Variance:  0.15358361774744028 Error:  0.05515358361774744
#
#
# svm: kernel=linear C=10 gamma=0.01
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        44
#            2       1.00      1.00      1.00        50
#            3       1.00      0.98      0.99        66
#            4       0.99      1.00      1.00       133
#
#     accuracy                           1.00       293
#    macro avg       1.00      1.00      1.00       293
# weighted avg       1.00      1.00      1.00       293
#
# svm_clf||                Bias:  0.010051194539249146 Variance:  0.0034129692832764505 Error:  0.0069795221843003425
# SVC(C=10, gamma=0.01, kernel='linear')
